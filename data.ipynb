# %%
from openpyxl import Workbook

# Create workbook and sheet
wb = Workbook()
ws = wb.active
ws.title = "YouTube_Trending_Summary"

# CSV data as rows
rows = [
    ["table_source","rank","video_title","channel_name","category_or_genre","countries_reached","unique_videos","days_trending","first_seen","last_seen"],
    ["Global Reach",1,"Apple Event — September 7","Apple","Science & Technology",104,"","","",""],
    ["Global Reach",2,"Every Country On Earth Fights For $250,000!","MrBeast","Entertainment",104,"","","",""],
    ["Global Reach",3,"BLACKPINK - 'Pink Venom' M/V","BLACKPINK","Music",104,"","","",""],
    ["Global Reach",4,"BLACKPINK - 'Shut Down' M/V","BLACKPINK","Music",103,"","","",""],
    ["Global Reach",5,"$1 Vs $100,000,000 Car!","MrBeast","Entertainment",103,"","","",""],
    ["Global Reach",6,"$1 vs $100,000,000 House!","MrBeast","Entertainment",103,"","","",""],
    ["Global Reach",7,"Jung Kook 'Seven' (feat. Latto)","HYBE LABELS","Music",103,"","","",""],
    ["Global Reach",8,"Grand Theft Auto VI Trailer 1","Rockstar Games","Gaming",103,"","","",""],
    ["Global Reach",9,"$1 vs $1,000,000,000 Yacht!","MrBeast","Entertainment",102,"","","",""],
    ["Global Reach",10,"50 YouTubers Fight For $1,000,000","MrBeast","Entertainment",102,"","","",""],

    ["US Channels",1,"","NFL","Sports","",323,"","",""],
    ["US Channels",2,"","NBA","Sports","",253,"","",""],
    ["US Channels",3,"","NBC Sports","Sports","",140,"","",""],
    ["US Channels",4,"","CBS Sports Golazo","Sports","",124,"","",""],
    ["US Channels",5,"","FOX Soccer","Sports","",115,"","",""],
    ["US Channels",6,"","FORMULA 1","Sports","",104,"","",""],
    ["US Channels",7,"","The United Stand","Sports","",98,"","",""],
    ["US Channels",8,"","HYBE LABELS","Music","",96,"","",""],
    ["US Channels",9,"","First We Feast","Entertainment","",83,"","",""],
    ["US Channels",10,"","ESPN","Sports","",83,"","",""],

    ["US Longest Trending",1,"Beat Ronaldo Win $1,000,000","MrBeast","Entertainment","", "",147,"2024-12-01","2025-01-06"],
    ["US Longest Trending",2,"Every Country On Earth Fights For $250K","MrBeast","Entertainment","", "",147,"2023-08-20","2023-09-25"],
    ["US Longest Trending",3,"Devin Haney vs Ryan Garcia Highlights","DAZN Boxing","Sports","", "",146,"2024-04-21","2024-05-28"],
    ["US Longest Trending",4,"$10,000 Every Day You Survive Grocery","MrBeast","Entertainment","", "",146,"2023-12-03","2024-01-08"],
    ["US Longest Trending",5,"Escaping the LA Wildfires…","Royalty Family","People & Blogs","", "",145,"2025-01-20","2025-02-25"],
    ["US Longest Trending",6,"I Spent 100 Hours Inside the Pyramids!","MrBeast","Entertainment","", "",145,"2025-02-09","2025-03-17"],
    ["US Longest Trending",7,"Face Your Biggest Fear to Win $800,000","MrBeast","Entertainment","", "",144,"2024-02-11","2024-03-18"],
    ["US Longest Trending",8,"He Nearly Fell Off the Cliff 😬","Red Bull","Sports","", "",144,"2024-12-02","2025-01-08"],
    ["US Longest Trending",9,"I Survived 7 Days in an Abandoned City","MrBeast","Entertainment","", "",144,"2024-03-03","2024-04-08"],
    ["US Longest Trending",10,"$1 vs $100,000,000 House!","MrBeast","Entertainment","", "",143,"2023-10-15","2023-11-20"]
]

# Write rows
for row in rows:
    ws.append(row)

# Save file
file_path = r"C:\Users\abidh\Downloads\youtub_data\youtube_trending_summary.xlsx"
wb.save(file_path)

file_path
# Out:
# 'C:\\Users\\abidh\\Downloads\\youtub_data\\youtube_trending_summary.xlsx'

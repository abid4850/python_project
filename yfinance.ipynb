# %%
import yfinance as yf

tickers = ["TSLA", "BYDDF", "TM"]

data = yf.download(
    tickers,
    start="2018-01-01",
    end="2026-02-06"
)

# Save for Kaggle
data.to_csv("auto_company_comparison.csv")
# Out:
# [*********************100%***********************]  3 of 3 completed
